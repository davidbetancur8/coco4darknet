# %% [markdown]
# Example of trainning darknet on a specific dataset if the dataset was created using https://github.com/davidbetancur8/coco4darknet and uploaded to google drive

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# !git clone https://github.com/AlexeyAB/darknet.git

# %%
cp -r /content/drive/My\ Drive/trascender/coco_person.zip darknet/data/

# %%
# !unzip -qq darknet/data/coco_person.zip -d darknet/data/

# %%
# %cd darknet/
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !sed -i "s/ARCH= -gencode arch=compute_60,code=sm_60/ARCH= -gencode arch=compute_${compute_capability},code=sm_${compute_capability}/g" Makefile
# !make -s

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# !./darknet detector train data/coco_person/coco_person.data data/coco_person/yolov4_person.cfg yolov4.conv.137 -dont_show -map
